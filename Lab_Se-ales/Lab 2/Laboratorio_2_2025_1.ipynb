# %% [markdown]
# # Laboratorio # 2: Explorando señales con Python
#
# Integrantes:
#
# Sergio Alejandro Mora Roa
#
# Yamid Azcarate Navarro

# %% [markdown]
# # **Marco teórico**

# %% [markdown]
# ## **1. Definición de funciones básicas: rampa, escalón unitario e impulso unitario.**

# %%
import numpy as np
import matplotlib.pyplot as plt

def ramp(t, delay):
    """
    ramp: función rampa
    u = (t + delay) si t >= -delay
    u = 0 en otro caso
    """
    u = np.where(t >= -delay, t + delay, 0)
    return u

def unitStep(t, delay):
    """
    unitStep: función escalón unitario
    u = 1 si t >= -delay
    u = 0 en otro caso
    """
    u = np.where(t >= -delay, 1, 0)
    return u

def unit_impulse(delay):
    # Crear una secuencia de tiempo discreta
    n = np.arange(-10, 11)

    # Crear la señal del impulso unitario con el corrimiento
    impulse = np.zeros_like(n)
    impulse[n == -delay] = 1

    # Graficar la señal del impulso unitario
    plt.stem(n, impulse)
    plt.xlabel('n')
    plt.ylabel('Amplitud')
    plt.title(f'Impulso Unitario con Corrimiento ({delay})')
    plt.xticks(np.arange(min(n), max(n)+1, 1))  
    plt.grid(True)
    plt.show()

    return

# %% [markdown]
# ## **2. Ejemplos.**

# %% [markdown]
# ### - Escalón unitario: $u(-t-3)$

# %%
# Se genera un vector t con los valores de tiempo
t = np.linspace(-10, 10, 1000)

# Se define el valor de delay para el escalón
delay_escalon = -3

#  Se calcula la función escalón
u_escalon = unitStep(-t, delay_escalon)

# Se grafica la función escalón
plt.plot(t, u_escalon, label='Escalón') # Se grafica la función escalón
plt.xlabel('Tiempo') # Se etiqueta el eje x
plt.ylabel('Valor') # Se etiqueta el eje y
plt.title('Función Escalón') # Se coloca un título a la gráfica
plt.xticks(np.arange(min(t), max(t)+1, 1))  # Se ajustan los valores del eje x
plt.legend() # Se coloca la leyenda
plt.grid(True) # Se activa la malla
plt.show() # Se muestra la gráfica

# %% [markdown]
# ### - Rampa: $r(t-3)$

# %%
# Se genera un vector t con los valores de tiempo
t = np.linspace(-10, 10, 1000)

# Se define el valor de delay para el escalón
delay_rampa = -3

#  Se calcula la función rampa
u_rampa = ramp(t, delay_rampa)

# Se grafica la función rampa
plt.plot(t, u_rampa, label='Rampa') # Se grafica la función rampa
plt.xlabel('Tiempo') # Se etiqueta el eje x
plt.ylabel('Valor') # Se etiqueta el eje y
plt.title('Función Rampa') # Se coloca el título de la gráfica
plt.xticks(np.arange(min(t), max(t)+1, 1))  # Se ajustan los valores del eje x
plt.legend() # Se coloca la leyenda
plt.grid(True)  # Se activa la cuadrícula
plt.show()  # Se muestra la gráfica

# %% [markdown]
# ### - Impulso unitario $\delta(t-3)$

# %%
# Se define el valor de delay para el impulso
delay_impulso = -3

#  Se calcula y grafica la función impulso
unit_impulse(delay_impulso)

# %% [markdown]
# # **Punto 1**

# %% [markdown]
# Grafique las siguientes señales:
#
# 1.   $1.5 \cdot u(t + 8)$
# 2.   $2 \cdot u(- t - 4)$
# 3.   $u(6t - 3)$
# 4.   $2 \cdot r(- t)$
# 5.   $-2 \cdot r(t)$
# 6.   $r(\frac{t}{4} - 4)$
# 7.   $δ(t - 4)$
# 8.   $δ(t + 3)$

# %% [markdown]
# ## 1.

# %%
import numpy as np
import matplotlib.pyplot as plt

def unitStep(t, delay,factor_escala):
    '''unitStep: función escalón unitario
    u = 1 si t <= -delay
    u = 0 en otro caso'''
    u = np.where(t <= -delay, 1*factor_escala, 0)
    
    return u



factor_escala = 1.5

t = np.linspace(-10, 10, 1000)

delay_escalon = -8

u_escalon = unitStep(-t, delay_escalon, factor_escala)

plt.plot(t, u_escalon, label='Escalón') # Se grafica la función escalón
plt.xlabel('Tiempo') # Se etiqueta el eje x
plt.ylabel('Valor') # Se etiqueta el eje y
plt.title('Función Escalón') # Se coloca un título a la gráfica
plt.xticks(np.arange(min(t), max(t)+1, 1))  # Se ajustan los valores del eje x
plt.legend() # Se coloca la leyenda
plt.grid(True) # Se activa la malla
plt.show() # Se muestra la gráfica

# %% [markdown]
# ## 2.

# %%
def unitStep_reflex(t, delay,factor_escala):
    '''unitStep: función escalón unitario
    u = 1 si t >= -delay
    u = 0 en otro caso'''
    u = np.where(t >= -delay, 1*factor_escala, 0)
    
    return u

factor_escala = 2

t = np.linspace(-10, 10, 1000)

delay_escalon = -4

u_escalon = unitStep_reflex(-t, delay_escalon, factor_escala)

plt.plot(t, u_escalon, label='Escalón') # Se grafica la función escalón
plt.xlabel('Tiempo') # Se etiqueta el eje x
plt.ylabel('Valor') # Se etiqueta el eje y
plt.title('Función Escalón') # Se coloca un título a la gráfica
plt.xticks(np.arange(min(t), max(t)+1, 1))  # Se ajustan los valores del eje x
plt.legend() # Se coloca la leyenda
plt.grid(True) # Se activa la malla
plt.show() # Se muestra la gráfica

# %% [markdown]
# ## 3.

# %%
def unitStep_compresion(t, delay, factor_escala, compresion):
    '''unitStep: función escalón unitario
    u = 1 si t >= -delay
    u = 0 en otro caso'''
    n = compresion * t
    u = np.where(n >= -delay, 1*factor_escala, 0)
    
    return u

compresion = 6

factor_escala = 1

t = np.linspace(-10, 10, 1000)

delay_escalon = 3

u_escalon = unitStep_compresion(-t, delay_escalon, factor_escala, compresion)

plt.plot(t, u_escalon, label='Escalón') # Se grafica la función escalón
plt.xlabel('Tiempo') # Se etiqueta el eje x
plt.ylabel('Valor') # Se etiqueta el eje y
plt.title('Función Escalón') # Se coloca un título a la gráfica
plt.xticks(np.arange(min(t), max(t)+1, 1))  # Se ajustan los valores del eje x
plt.legend() # Se coloca la leyenda
plt.grid(True) # Se activa la malla
plt.show() # Se muestra la gráfica

# %% [markdown]
# ## 4.

# %%
def ramp_refelx(t, delay, factor_escala):
    """
    ramp: función rampa
    u = (t + delay) si t >= -delay
    u = 0 en otro caso
    """
    u = np.where(-t >= -delay, (-t + delay)*factor_escala, 0)
    return u

t = np.linspace(-10, 10, 1000)

# Se define el valor de delay para el escalón
delay_rampa = 0

factor_escala = 2

#  Se calcula la función rampa
u_rampa = ramp_refelx(t, delay_rampa,factor_escala)

# Se grafica la función rampa
plt.plot(t, u_rampa, label='Rampa') # Se grafica la función rampa
plt.xlabel('Tiempo') # Se etiqueta el eje x
plt.ylabel('Valor') # Se etiqueta el eje y
plt.title('Función Rampa') # Se coloca el título de la gráfica
plt.xticks(np.arange(min(t), max(t)+1, 1))  # Se ajustan los valores del eje x
plt.legend() # Se coloca la leyenda
plt.grid(True)  # Se activa la cuadrícula
plt.show()  # Se muestra la gráfica

# %% [markdown]
# ## 5.

# %%
def ramp_refelx_x(t, delay, factor_escala):
    """
    ramp: función rampa
    u = (t + delay) si t >= -delay
    u = 0 en otro caso
    """
    u = np.where(t >= -delay, (t + delay)*factor_escala, 0)
    return u

t = np.linspace(-10, 10, 1000)

# Se define el valor de delay para el escalón
delay_rampa = 0

factor_escala = -2

#  Se calcula la función rampa
u_rampa = ramp_refelx_x(t, delay_rampa,factor_escala)

# Se grafica la función rampa
plt.plot(t, u_rampa, label='Rampa') # Se grafica la función rampa
plt.xlabel('Tiempo') # Se etiqueta el eje x
plt.ylabel('Valor') # Se etiqueta el eje y
plt.title('Función Rampa') # Se coloca el título de la gráfica
plt.xticks(np.arange(min(t), max(t)+1, 1))  # Se ajustan los valores del eje x
plt.legend() # Se coloca la leyenda
plt.grid(True)  # Se activa la cuadrícula
plt.show()  # Se muestra la gráfica

# %% [markdown]
# ## 6.

# %%
def ramp_refelx_x(t, delay, factor_escala):
    """
    ramp: función rampa
    u = (t + delay) si t >= -delay
    u = 0 en otro caso
    """
    u = np.where(t/4 >= -delay, (t/4 + delay)*factor_escala, 0)
    return u

t = np.linspace(-10, 10, 1000)

# Se define el valor de delay para el escalón
delay_rampa = 4

factor_escala = 1

#  Se calcula la función rampa
u_rampa = ramp_refelx_x(t, delay_rampa,factor_escala)

# Se grafica la función rampa
plt.plot(t, u_rampa, label='Rampa') # Se grafica la función rampa
plt.xlabel('Tiempo') # Se etiqueta el eje x
plt.ylabel('Valor') # Se etiqueta el eje y
plt.title('Función Rampa') # Se coloca el título de la gráfica
plt.xticks(np.arange(min(t), max(t)+1, 1))  # Se ajustan los valores del eje x
plt.legend() # Se coloca la leyenda
plt.grid(True)  # Se activa la cuadrícula
plt.show()  # Se muestra la gráfica

# %% [markdown]
# ## 7.

# %%
def unit_impulse(delay):
    # Crear una secuencia de tiempo discreta
    n = np.arange(-10, 11)

    # Crear la señal del impulso unitario con el corrimiento
    impulse = np.zeros_like(n)
    impulse[n == -delay] = 1

    # Graficar la señal del impulso unitario
    plt.stem(n, impulse)
    plt.xlabel('n')
    plt.ylabel('Amplitud')
    plt.title(f'Impulso Unitario con Corrimiento ({delay})')
    plt.xticks(np.arange(min(n), max(n)+1, 1))  
    plt.grid(True)
    plt.show()

    return

delay_impulse = -4

unit_impulse(delay_impulse)

# %% [markdown]
# ## 8.

# %%
delay_impulse = 3

unit_impulse(delay_impulse)

# %% [markdown]
# # **Punto 2**

# %% [markdown]
# Construya la señal que se muestra en la guía de laboratorio

# %%
def función_trozos():

    t = np.linspace(-10, 10, 1000)

    y0 = 2*ramp(t, 9)
    y1 = -4*ramp(t, 8)
    y2 = 2*ramp(t, 5)
    y3 = unitStep(t, 4)
    y4 = -unitStep(t, 3)
    y5 = -unitStep(t, 2)
    y6 = -unitStep(t, 0)
    y7 = 3*unitStep(t, -1)
    y8 = ramp(t, -1)
    y9 = -2*ramp(t, -2)
    

    y = y0 + y1 + y2 + y3 + y4 + y5 + y6 + y7 + y8 + y9 
    plt.plot(t, y)

función_trozos()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 20
#      17     y = y0 + y1 + y2 + y3 + y4 + y5 + y6 + y7 + y8 + y9
#      18     plt.plot(t, y)
# ---> 20 función_trozos()
#
# Cell In[14], line 8, in función_trozos()
#       6 y1 = -4*ramp(t, 8)
#       7 y2 = 2*ramp(t, 5)
# ----> 8 y3 = unitStep(t, 4)
#       9 y4 = -unitStep(t, 3)
#      10 y5 = -unitStep(t, 2)
#
# TypeError: unitStep() missing 1 required positional argument: 'factor_escala'
