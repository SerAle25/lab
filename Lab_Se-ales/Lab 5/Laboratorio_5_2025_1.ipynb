# %% [markdown]
# # Laboratorio 5
# ## Integrantes
#
# ######################################
#
# ######################################

# %% [markdown]
# **Punto 1:** Cargar y visualizar la imagen

# %%
import matplotlib.pyplot as plt
from scipy import ndimage
import cv2
import numpy as np

# Cargar la imagen en blanco y negro
orgImg = cv2.imread(, cv2.IMREAD_GRAYSCALE) #recibe la ruta de la imagen

# Visualizar la imagen original
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.title('Imagen Original')
plt.imshow(orgImg, cmap='gray')

plt.show()

# %% [markdown]
# **Punto 2:**
# Definir los filtros

# %%
# Crear matrices de los filtros a utilizar

# %% [markdown]
# Aplique y visualice los filtros

# %%
#COPIAR ESTA CELDA PARA APLICAR TODOS LOS FILTROS
# Aplicar el filtro
filteredImg = cv2.filter2D( ,cv2.CV_32F, ) #recibe como argumentos la imagen original y el filtro

# Visualizar la imagen original y la imagen filtrada en subplots
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.title('Imagen Original')
plt.imshow(, cmap='gray')

plt.subplot(1, 2, 2)
plt.title('')
plt.imshow(, cmap='gray')

plt.show()
